# %%
# %matplotlib inline 
# magic function to show charts besides code
# import matplotlib # ---> not to import the whole library
from matplotlib import pyplot as plt # only import the required module.
plt.plot([1,2,3],[2,5,7])
plt.show()

# %%
# %matplotlib inline 
# magic function to show charts besides code
# import matplotlib # ---> not to import the whole library
from matplotlib import pyplot as plt # only import the required module.
plt.plot([1,2,3],[2,5,7])
plt.title("Sids Data")
plt.ylabel("this is y")
plt.xlabel("this is x")
plt.show()

# %%
from matplotlib import pyplot as plt
from matplotlib import style
style.use('ggplot')
x=[1,5,4]
y=[23,45,89]
x2=[3,7,3]
y2=[5,8,9]
plt.scatter(x,y, label= 'first', linewidth= 8)
plt.plot(x2,y2,  label= 'second')
plt.legend() # labels work only when this function is called
